# %%
import requests
from bs4 import BeautifulSoup
import os
import json
import itertools
import csv
import re

# %%
url = "https://www.dmm.co.jp/digital/videoa/-/genre/"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
firstpage_url = soup.find('a', class_="ageCheck__link ageCheck__link--r18").get('href')
res2 = requests.get(firstpage_url)
soup2 = BeautifulSoup(res2.text, 'html.parser')

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html lang="ja" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <title>ジャンル一覧 | カテゴリー別 - エロ動画・アダルトビデオ - FANZA動画</title>
# <meta content="【FANZA(ファンザ)】 エロ動画・アダルトビデオのカテゴリー別ジャンル一覧。プレイ内容やシチュエーション、コスチュームなどジャンル別に紹介！" name="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
data = soup2.find("div", id="genre_list_box")

# %%
data
# Out:
# <div id="genre_list_box">
# <dig-pc-genre-list json-data='[[{"genre_id":2001,"genre":"\u5de8\u4e73"},{"genre_id":1014,"genre":"\u719f\u5973"},{"genre_id":1034,"genre":"\u30ae\u30e3\u30eb"},{"genre_id":1039,"genre":"\u4eba\u59bb\u30fb\u4e3b\u5a66"},{"genre_id":1018,"genre":"\u5973\u5b50\u6821\u751f"},{"genre_id":5001,"genre":"\u4e2d\u51fa\u3057"},{"genre_id":5005,"genre":"\u30a2\u30ca\u30eb"},{"genre_id":4015,"genre":"\u30cb\u30e5\u30fc\u30cf\u30fc\u30d5"},{"genre_id":6793,"genre":"VR\u5c02\u7528"},{"genre_id":79015,"genre":"4K"}],"videoa"]'></dig-pc-genre-list>
# ...

# %%
d = data.text

# %%
r = re.findall('{genre_id}: {genre}', d)

# %%
r
# Out:
# []
