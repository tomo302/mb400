# %%
import requests
from bs4 import BeautifulSoup
import os
import json
import itertools
import csv

# %%
url = "https://www.dmm.co.jp/digital/videoa/-/genre/"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
res2 = requests.get(soup.find('a', class_="ageCheck__link ageCheck__link--r18").get('href'))
soup2 = BeautifulSoup(res2.text, 'html.parser')

# %%
data = ""

# %%
json_2 = soup2.find('div', id= "genre_list_box").encode().decode('unicode-escape')

# %%
data = json_2.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [200], in <cell line: 1>()
# ----> 1 data = json_2.text
#
# AttributeError: 'str' object has no attribute 'text'

# %%
#data = json_2.split('[')[5].split(']')[0].replace('[', '').replace(']', '').replace('\n', '').replace("'", "")

# %%
data
# Out:
# '{"genre_id":"4118","genre":"アイドル・芸能人"},{"genre_id":"6968","genre":"アクメ・オーガズム"},{"genre_id":"6965","genre":"アスリート"},{"genre_id":"4057","genre":"姉・妹"},{"genre_id":"4122","genre":"イタズラ"},{"genre_id":"1004","genre":"インストラクター"},{"genre_id":"1040","genre":"ウェイトレス"},{"genre_id":"6942","genre":"受付嬢"},{"genre_id":"4119","genre":"エステ"},{"genre_id":"5074","genre":"M男"},{"genre_id":"6967","genre":"M女"},{"genre_id":"1001","genre":"OL"},{"genre_id":"1032","genre":"お母さん"},{"genre_id":"1003","genre":"女将・女主人"},{"genre_id":"1083","genre":"幼なじみ"},{"genre_id":"6934","genre":"お爺ちゃん"},{"genre_id":"527","genre":"お嬢様・令嬢"},{"genre_id":"6954","genre":"オタク"},{"genre_id":"6938","genre":"オナサポ"},{"genre_id":"1033","genre":"お姉さん"},{"genre_id":"6947","genre":"お婆ちゃん"},{"genre_id":"6943","genre":"叔母さん"},{"genre_id":"528","genre":"お姫様"},{"genre_id":"6969","genre":"お風呂"},{"genre_id":"4140","genre":"温泉"},{"genre_id":"1016","genre":"女教師"},{"genre_id":"6945","genre":"女上司"},{"genre_id":"1082","genre":"女戦士"},{"genre_id":"2
# ...

# %%
//div[2]/div/div[1]/ul/li/a/p

# %%
soup2.find_all('ul', class_ ="seo-genre-list")
# Out:
# []

# %%
data = json.dumps(data)

# %%
jd = ""

# %%
jd = json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [199], in <cell line: 1>()
# ----> 1 jd = json.loads(data)
#
# File /usr/lib64/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib64/python3.10/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# ...

# %%
<ul data-v-02cb2b3f="" class="seo-genre-list"><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=4118/"><p data-v-02cb2b3f=""> アイドル・芸能人 </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=6968/"><p data-v-02cb2b3f=""> アクメ・オーガズム </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=6965/"><p data-v-02cb2b3f=""> アスリート </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=4057/"><p data-v-02cb2b3f=""> 姉・妹 </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=4122/"><p data-v-02cb2b3f=""> イタズラ </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=1004/"><p data-v-02cb2b3f=""> インストラクター </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=1040/"><p data-v-02cb2b3f=""> ウェイトレス </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=6942/"><p data-v-02cb2b3f=""> 受付嬢 </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=4119/"><p data-v-02cb2b3f=""> エステ </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=5074/"><p data-v-02cb2b3f=""> M男 </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=6967/"><p data-v-02cb2b3f=""> M女 </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=1001/"><p data-v-02cb2b3f=""> OL </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=1032/"><p data-v-02cb2b3f=""> お母さん </p></a></li><li data-v-02cb2b3f="" style="width: 164px;"><a data-v-02cb2b3f="" href="https://www.dmm.co.jp/digital/videoa/-/list/=/article=keyword/id=
# ...

# %%
jd.encode().decode('unicode-escape')
# Out:
# '"{"genre_id":"4118","genre":"アイドル・芸能人"},{"genre_id":"6968","genre":"アクメ・オーガズム"},{"genre_id":"6965","genre":"アスリート"},{"genre_id":"4057","genre":"姉・妹"},{"genre_id":"4122","genre":"イタズラ"},{"genre_id":"1004","genre":"インストラクター"},{"genre_id":"1040","genre":"ウェイトレス"},{"genre_id":"6942","genre":"受付嬢"},{"genre_id":"4119","genre":"エステ"},{"genre_id":"5074","genre":"M男"},{"genre_id":"6967","genre":"M女"},{"genre_id":"1001","genre":"OL"},{"genre_id":"1032","genre":"お母さん"},{"genre_id":"1003","genre":"女将・女主人"},{"genre_id":"1083","genre":"幼なじみ"},{"genre_id":"6934","genre":"お爺ちゃん"},{"genre_id":"527","genre":"お嬢様・令嬢"},{"genre_id":"6954","genre":"オタク"},{"genre_id":"6938","genre":"オナサポ"},{"genre_id":"1033","genre":"お姉さん"},{"genre_id":"6947","genre":"お婆ちゃん"},{"genre_id":"6943","genre":"叔母さん"},{"genre_id":"528","genre":"お姫様"},{"genre_id":"6969","genre":"お風呂"},{"genre_id":"4140","genre":"温泉"},{"genre_id":"1016","genre":"女教師"},{"genre_id":"6945","genre":"女上司"},{"genre_id":"1082","genre":"女戦士"},{"genre_id":"
# ...

# %%
jd[1]
# Out:
# '{'

# %%
for row in jd:
    print(row)
# Out:
# "
# {
# \
# "
# g
# e
# n
# r
# e
# _
# i
# d
# \
# "
# :
# \
# "
# 4
# 1
# 1
# 8
# \
# "
# ,
# \
# "
# g
# e
# n
# r
# e
# \
# "
# :
# \
# "
# \
# u
# 3
# 0
# a
# 2
# \
# u
# 3
# 0
# a
# 4
# \
# u
# 3
# 0
# c
# 9
# \
# u
# 3
# 0
# e
# b
# \
# u
# 3
# 0
# f
# b
# \
# u
# 8
# 2
# b
# 8
# \
# u
# 8
# 0
# f
# d
# \
# u
# 4
# e
# b
# a
# \
# "
# }
# ,
# {
# \
# "
# g
# e
# n
# r
# e
# _
# i
# d
# \
# "
# :
# \
# "
# 6
# 9
# 6
# 8
# \
# "
# ,
# \
# "
# g
# e
# n
# r
# e
# \
# "
# :
# \
# "
# \
# u
# 3
# 0
# a
# 2
# \
# u
# 3
# 0
# a
# f
# \
# u
# 3
# 0
# e
# 1
# \
# u
# 3
# 0
# f
# b
# \
# u
# 3
# 0
# a
# a
# \
# u
# 3
# 0
# f
# c
# \
# u
# 3
# 0
# a
# c
# \
# u
# 3
# 0
# b
# a
# \
# u
# 3
# 0
# e
# 0
# \
# "
# }
# ,
# {
# \
# "
# g
# e
# n
# r
# e
# _
# i
# d
# \
# "
# :
# \
# "
# 6
# 9
# 6
# 5
# \
# "
# ,
# \
# "
# g
# e
# n
# r
# e
# \
# "
# :
# \
# "
# \
# u
# 3
# 0
# a
# 2
# \
# u
# 3
# 0
# b
# 9
# \
# u
# 3
# 0
# e
# a
# \
# u
# 3
# 0
# f
# c
# \
# u
# 3
# 0
# c
# 8
# \
# "
# }
# ,
# ...
