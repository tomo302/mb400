# %%
import requests
from bs4 import BeautifulSoup
import os
import json
import itertools
import csv

# %%
url = "https://www.dmm.co.jp/digital/videoa/-/list/=/article=actress/id=1010339/?dmmref=umso00459&i3_ref=detail&i3_ord=1&i3_pst=info_actress"

# %%
base_url = ""

# %%
# URLはgenruページのURLを期待しているが・・・出演作品一覧でも
def genru(url):
    base_url = url + "page="

    
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    firstpage_url = soup.find('a', class_="ageCheck__link ageCheck__link--r18").get('href')
    res2 = requests.get(firstpage_url)
    soup2 = BeautifulSoup(res2.text, 'html.parser')
    #最大ページ数
    max_page = int(soup2.find('div', class_ = "list-boxcaptside list-boxpagenation").p.text.split('タ')[0].replace(',', '')) // 120 + 2
    #ジャンル名
    genru_name = (soup2.title.text.split('- エ')[0])
    #print(max_page)
    genru_lists = []
    actor_lists = []
    for num in range(1, max_page):
        print(num)
        url = base_url + str(num) + "/"
        print(url)
        res3 = requests.get(url)
        #print(res3.status_code)
        soup3 = BeautifulSoup(res3.text, 'html.parser')
        res4 = requests.get(soup3.find('a', class_="ageCheck__link ageCheck__link--r18").get('href'))
        soup4 = BeautifulSoup(res4.text, 'html.parser')
        #print(soup4.title)
        #出演者名取得　例外処理必要
        for _ in soup4.find_all('p', class_ = 'sublink'):
            try:
                print(_.a.text)
                actor_name = _.a.text
                actor_lists.append(actor_name)
            except AttributeError:
                print("出演者：複数")
                actor_name = "出演者：複数"
                actor_lists.append(actor_name)
        #作品タイトル、　作品ページURL、　DVDジャケット表画像URL
        for row in soup4.find_all('p', class_ = 'tmb'):
            print(row.img['alt'])
            sakuhin_title = row.img['alt']
            sakuhin_url = row.a['href']
            dvd_jaketo_omote = row.img['src']
        
            genru_lists.append([sakuhin_title, sakuhin_url, dvd_jaketo_omote])
    return genru_lists, actor_lists, genru_name

# %%
g_lists, act_list, genru_name = genru(url)
# Out:
# 1
# https://www.dmm.co.jp/digital/videoa/-/list/=/article=actress/id=1010339/?dmmref=umso00459&i3_ref=detail&i3_ord=1&i3_pst=info_actresspage=1/
# ゑびすさん/妄想族
# ケイ・エム・プロ...
# アロマ企画
# SEX Agent/妄想族
# SEX Agent/妄想族
# SEX Agent/妄想族
# AVS collector’s
# イノセント/妄想族
# AVS collector’s
# なでしこ
# ゑびすさん/妄想族
# イノセント/妄想族
# SEX Agent/妄想族
# ゑびすさん/妄想族
# アロマ企画
# ゑびすさん/妄想族
# イノセント/妄想族
# アロマ企画
# キチックス/妄想族
# エンペラー/妄想族
# エンペラー/妄想族
# エンペラー/妄想族
# ミニマム
# ミニマム
# ディープス
# TMA
# シネマジック
# レズれ！
# ROOKIE
# ケイ・エム・プロ...
# レズれ！
# シネマジック
# ROCKET
# ROOKIE
# ミニマム
# ミニマム
# TMA
# レズれ！
# セレブの友
# V＆R PRODUCE
# OFFICE K’S
# TMA
# レズれ！
# レズれ！
# プラネットプラス
# レズれ！
# ディープス
# OFFICE K’S
# ケー・トライブ
# レズれ！
# V＆R PRODUCE
# ディープス
# kawaii
# ムーディーズ
://www.dmm.co.jp/digital/videoa/-/detail/=/cid=inct00026/', 'https://pics.dmm.co.jp/digital/video/inct00026/inct00026ps.jpg'], ['SEX Agent/妄想族', 'スク水萌え脚コキ', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=436agemix00132/', 'https://pics.dmm.co.jp/digital/video/436agemix00132/436agemix00132ps.jpg'], ['ゑびすさん/妄想族', '敏感な勃起乳首を舐めるレズ9', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=evis00133/', 'https://pics.dmm.co.jp/digital/video/evis00133/evis00133ps.jpg'], ['アロマ企画', '直下型＆M字パンチラ挑発 ベストセレクション', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=parm00092/', 'https://pics.dmm.co.jp/digital/video/parm00092/parm00092ps.jpg'], ['ゑびすさん/妄想族', '3日以上はき込んだ染み付き汚れパンツをまん汁で更に汚す女子校生のオナニー2', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=evis00042/', 'https://pics.dmm.co.jp/digital/video/evis00042/evis00042ps.jpg'], ['イノセント/妄想族', '人形あそび 初芽里奈', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=inct00009/', 'https://pics.dmm.co.jp/digital/video/inct00009/inct00009ps.jpg'], ['アロマ企画', '直下型＆M字パンチラ挑発 スポーツ女子校生編', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=11parm00047/', 'https://pics.dmm.co.jp/digital/video/11parm00047/11parm00047ps.jpg'], ['キチックス/妄想族', 'ミクロ はつめちゃん 147cm', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=ktkx00032/', 'https://pics.dmm.co.jp/digital/video/ktkx00032/ktkx00032ps.jpg'], ['エンペラー/妄想族', '生中出し痴●便所4時間 仕事終わりのアフタートイレ痴●濃厚生中出し陵●アクメ！', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=emrd00044/', 'https://pics.dmm.co.jp/digital/video/emrd00044/emrd00044ps.jpg'], ['エンペラー/妄想族', '私が満足するまでイッたらダメよ？焦らし好きのオナニー美少女が挑発的な見せつけ遊戯で貴方だけに語りかけるオナニー専用のオナニーDVD', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=emrd00041/', 'https://pics.dmm.co.jp/digital/video/emrd00041/emrd00041ps.jpg'], ['エンペラー/妄想族', '美白美巨乳少女のものすごいオナニー！オナニーをする為の専用DVD！！', 'https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=emrd00038/', 'https://pics.dmm.co.jp/digital/video/emrd00038/emrd00038ps.jpg'], ['ミニマム', '205X年、性教育。 光クラブ×ミニマム', 'https:/ ...

# %%
#labels = ['出演者名', '作品タイトル', '作品ページURL', 'DVDジャケット画像']
with open(genru_name + '.csv', 'a', newline="") as f:
    writer = csv.writer(f)
    writer.writerows(g_lists)

# %%
max_page = int(soup2.find('div', class_ = "list-boxcaptside list-boxpagenation").p.text.split('タ')[0].replace(',', '')) // 120
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 max_page = int(soup2.find('div', class_ = "list-boxcaptside list-boxpagenation").p.text.split('タ')[0].replace(',', '')) // 120
#
# AttributeError: 'NoneType' object has no attribute 'p'

# %%
actor_name = g_soup.find('p', class_ = 'sublink').a.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 actor_name = g_soup.find('p', class_ = 'sublink').a.text
#
# NameError: name 'g_soup' is not defined

# %%
sakuhin_title = g_soup.find_all('p', class_ = 'tmb')[0].img['alt']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 sakuhin_title = g_soup.find_all('p', class_ = 'tmb')[0].img['alt']
#
# NameError: name 'g_soup' is not defined

# %%
sakuhin_url = g_soup.find_all('p', class_ = 'tmb')[0].a['href']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 sakuhin_url = g_soup.find_all('p', class_ = 'tmb')[0].a['href']
#
# NameError: name 'g_soup' is not defined

# %%
dvd_jaketo_omote = g_soup.find_all('p', class_ = 'tmb')[0].img['src']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 dvd_jaketo_omote = g_soup.find_all('p', class_ = 'tmb')[0].img['src']
#
# NameError: name 'g_soup' is not defined

# %%
genru_list = []

# %%
os.getcwd()
# Out:
# 'C:\\Users\\i3-12100\\git\\mb400\\BASE'

# %%
#url = "https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=hhf00007/?dmmref=81b5e821-9a8f4f0a4d9f58928c89ef3b0f00aaa0&i3_ref=recommend&i3_ord=13"
#url = "https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=venx00159/?dmmref=recommend1_detail&i3_ref=recommend&i3_ord=3"
#出演者単独
url = "https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=venx00116/?dmmref=81b5e821-9a8f4f0a4d9f58928c89ef3b0f00aaa0&i3_ref=recommend&i3_ord=9"
#サンプル動画がない作品
#url = "https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=78godr00937/?dmmref=keyword_6960&i3_ref=list&i3_ord=19"
#url = "https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=jufe00419/?dmmref=videoa_top_pickup_pc&i3_ref=recommend&i3_ord=6"
#url = "https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=lulu00152/?dmmref=keyword_1018&i3_ref=list&i3_ord=96"
#url = "https://www.dmm.co.jp/digital/videoa/-/detail/=/cid=umso00459/?dmmref=actress_1069702&i3_ref=list&i3_ord=67"
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
firstpage_url = soup.find('a', class_="ageCheck__link ageCheck__link--r18").get('href')
res2 = requests.get(firstpage_url)
soup2 = BeautifulSoup(res2.text, 'html.parser')

# %%
#soup2.title.text.split("-")[0]

# %%
dvd_jacket_url = soup2.find("div", class_ = "tx10 pd-3").a['href']

# %%
video_title = soup2.find("img", class_ ="tdmm")['alt']

# %%
#出演者複数作品の出演者１０名まで取得可能・・取得値は参考までで使用していない。
actors = ""
for a in soup2.find('span', id = 'performer').find_all('a'):
    b = a.text.replace('▼すべて表示する', '') + ','
    actors = actors + b
actors = actors.replace(',,', '')
print(actors)
# Out:
# 大石紗季,

# %%
json_2 = soup2.find("script", {"type": "application/ld+json"})

# %%
data = json_2.text

# %%
json_dict = None

# %%
def get_sakuhin_data():
    #サンプル画像URL取得
    sample_gazou = []
    for _ in soup2.find_all("img", class_ ="mg-b6"):
        sample_gazou.append(_['src'])
    #ENDーサンプル画像
    
    #作品データ詳細取得：作品タイトル、作品内容詳細、作品内画像URL、DVDジャケット見開き画像URL、サンプル動画URL、出演者名
    json_2 = soup2.find("script", {"type": "application/ld+json"})
    data = json_2.text
    json_dict = None
    #サンプル動画の有無を確認
    if "subjectOf" in data and "contentUrl" in data:
        json_dict = json.loads(data)
        
        sakuhin_name = json_dict['name']
        sakuhin_description = json_dict['description']
        sakuhin_image = json_dict['image']
        dvd_jacket_url = soup2.find("div", class_ = "tx10 pd-3").a['href']
        sample_video_url = json_dict['subjectOf']['contentUrl']#デフォルットだと小さい画像なので
        
        # 出演者が複数の場合の処理
        try:
            actor_name = json_dict['subjectOf']['actor']['name']
        except KeyError:
            actor_name = "出演者複数"
            print(actor_name)
            
        #サンプル画像URLを取得してリストで保存    
        sample_gazou = []
        for _ in soup2.find_all("img", class_ ="mg-b6"):
            sample_gazou.append(_['src'])
        
    #取得してリターンする値：：作品タイトル、作品内容詳細、作品内画像URL、DVDジャケット見開き画像URL、サンプル動画URL、出演者名、作品サンプル画像
    sakuhin_list = [json_dict['name'], json_dict['description'], json_dict['image'], dvd_jacket_url, json_dict['subjectOf']['contentUrl'].replace('sm', 'mhb'), actor_name, sample_gazou] 
    
    #return sakuhin_name, sakuhin_description, sakuhin_image, sample_video_url
    return sakuhin_list

# %%
def sakuhin_down(sakuhin_list):
    BASE_PATH = "/home/fed36-mb400/git/mb400/FANZA/"
    os.chdir(BASE_PATH)
    print(BASE_PATH)
    actor_name = sakuhin_list[5]
    if actor_name not in os.listdir():
        #女優名フォルダが存在しなかったら、女優名でフォルダ作成
        os.makedirs(actor_name)
        #作成したフォルダにCD
        os.chdir(actor_name)
    else:
        #既存の女優名のフォルダにCD
        os.chdir(actor_name)
       
    sakuhin_title = sakuhin_list[0]
    #現在女優のフォルダ内・・作品名のフォルダが存在しなかったら作品名でフォルダ作成 
    if sakuhin_title not in os.listdir():
        #作品名でフォルダ作成
        os.makedirs(sakuhin_title)
        #作成したフォルダにCD
        os.chdir(sakuhin_title)
    else:
        os.chdir(sakuhin_title)
    #これ以降作品名のフォルダ内にサンプル画像、DVDジャケット画像、サンプル動画をダウンロードする
    response = requests.get(sakuhin_list[4])
    if response.status_code == 200:
        with open(os.getcwd() + '/' + sakuhin_title + '.mp4', 'wb') as saveFile:
            saveFile.write(response.content)
            print("ダウンロードしました")
    else:
        #大きい解像度の動画が存在しない場合は、URLを変更して小さい映像の動画をダウンロードする。
        sakuhin_title = sakuhin_title.replace('mhb', 'sm')
        with open(os.getcwd() + sakuhin_title + '.mp4', 'wb') as saveFile:
            saveFile.write(response.content)
            print("解像度の低い動画をダウンロードしました")
    
    return sakuhin_title

# %%
sakuhin_list = get_sakuhin_data()

# %%
#カレント内のファイル名＆ディレクトリ名取得
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'fanza_final_20220904.ipynb',
#  'fanza_final_20220904.py',
#  'くノ一 .csv']

# %%
#os.chdir(sakuhin_list[5])

# %%
os.getcwd()
# Out:
# 'C:\\Users\\i3-12100\\git\\mb400\\BASE'

# %%
os.chdir("/home/fed36-mb400/git/mb400")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 os.chdir("/home/fed36-mb400/git/mb400")
#
# FileNotFoundError: [WinError 3] 指定されたパスが見つかりません。: '/home/fed36-mb400/git/mb400'

# %%
print(sakuhin_down(sakuhin_list))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 print(sakuhin_down(sakuhin_list))
#
# Input In [36], in sakuhin_down(sakuhin_list)
#       1 def sakuhin_down(sakuhin_list):
#       2     BASE_PATH = "/home/fed36-mb400/git/mb400/FANZA/"
# ----> 3     os.chdir(BASE_PATH)
#       4     print(BASE_PATH)
#       5     actor_name = sakuhin_list[5]
#
# FileNotFoundError: [WinError 3] 指定されたパスが見つかりません。: '/home/fed36-mb400/git/mb400/FANZA/'
