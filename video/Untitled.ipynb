# %%
import os

# %%
os.makedirs('FileExistsError')

# %%
# !ls
# Out:
#  FileExistsError
#  Untitled.ipynb
#  byActrese_url_video_download.py
#  fanza_down_test.py
#  fanza_move_down.py
#  sakuhin.ipynb
#  sakuhin.py
#  sakuhin_itiran.ipynb
#  video_name_custome_down.ipynb
# ''$'\343\201\262\343\201\237\343\201\231\343\202\211\347\276\216\345\260\221\345\245\263\343\201\253\351\241\224\351\235\242\345\260\204\347\262\276\343\203\251\343\203\203\343\202\267\343\203\245''BEST '$'\345\220\210\350\250\210\351\241\224\345\260\204''100'$'\347\231\272\343\202\252\343\203\274\343\203\220\343\203\274'

# %%
'pwd
# Out:
#   Input In [4]
#     'pwd
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# !pwd
# Out:
# /home/fed36-mb400/git/mb400/video
