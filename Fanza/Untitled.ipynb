# %%
# !pwd
# Out:
# /home/fed36-mb400/git/mb400/Fanza

# %%
import os

# %%
actor_name = "瀬田ちさと(せたちさ)"

# %%
if not os.path.isdir(actor_name):
    os.makedirs(actor_name)
print("つづくです")
# Out:
# つづくです
